# %%
import gymnasium as gym
import os
import numpy as np
import sys
sys.path.append(os.path.join("C:\\Users", "Manan", "OneDrive", "Documents", "orbit_project"))

import orbit_optimization_project
from orbit_optimization_project.orbit_env.orbit_env import OrbitEnv

from stable_baselines3 import A2C
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.callbacks import EvalCallback
from stable_baselines3.common.logger import configure
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.vec_env import VecNormalize
from stable_baselines3.common.callbacks import BaseCallback
#from stable_baselines3.common.buffer import RolloutBufferWithSampling
from torch.nn import LeakyReLU

from gymnasium.envs.registration import register

register(
    id='OrbitEnv-v0',
    entry_point='orbit_optimization_project.orbit_env:OrbitEnv',
    max_episode_steps=300
)

print("OrbitEnv-v0 registered successfully!")
# Out:
# OrbitEnv-v0 registered successfully!
# C:\Users\Manan\anaconda3\Lib\site-packages\gymnasium\envs\registration.py:644: UserWarning: WARN: Overriding environment OrbitEnv-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")

# %% [markdown]
# # Change working directory

# %%
os.chdir(r"C:\Users\Manan\OneDrive\Documents\orbit_project\orbit_optimization_project")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Manan\\OneDrive\\Documents\\orbit_project\\orbit_optimization_project'

# %% [markdown]
# # Creating Environment

# %%
raw_env = gym.make("OrbitEnv-v0")
# Out:
# Plotted 7528 satellites within altitude range (700.0, 1550.0)

# %%
raw_env.action_space.sample()
# Out:
# array([7.8338691e+03, 3.4118839e-02, 9.0207618e-01, 7.3306453e-01,
#        9.7540313e-01], dtype=float32)

# %% [markdown]
# # Creating vector environment

# %%
vec_env_raw = DummyVecEnv([lambda: raw_env])

# %% [markdown]
# # Normalize the vector environment -> Normalized obs and rewards

# %%
vec_env = VecNormalize( # Must be saved when model is saved
    vec_env_raw,
    norm_obs=True,
    norm_reward=True,
    clip_obs=10.0,
    norm_obs_keys = ["orbital_elements"]
)

# %%
vec_env.action_space.sample()
# Out:
# array([7.9742012e+03, 2.2472758e-02, 1.4649805e+00, 6.2033033e+00,
#        4.2948279e+00], dtype=float32)

# %% [markdown]
# # Logs and eval environment

# %%
log_dir = "./logs/"
os.makedirs(log_dir, exist_ok=True)

# Configuring logger to output logs to console and files
new_logger = configure(log_dir, ["stdout", "csv", "tensorboard"]) 

# Base evaluation env
eval_env_raw = gym.make('OrbitEnv-v0')
# seeding the environment
eval_env_raw.reset(seed=42)

eval_vec_env = DummyVecEnv([lambda:eval_env_raw])
eval_env = VecNormalize(
    eval_vec_env, 
    training=False, 
    norm_obs=True, 
    norm_reward=False,
    clip_obs=10.0,
    norm_obs_keys = ["orbital_elements"]
)
# Out:
# Logging to ./logs/
# Plotted 7528 satellites within altitude range (700.0, 1550.0)
# C:\Users\Manan\anaconda3\Lib\site-packages\gymnasium\utils\passive_env_checker.py:174: UserWarning: WARN: The default seed argument in `Env.reset` should be `None`, otherwise the environment will by default always be deterministic. Actual default: seed=42
#   logger.warn(

# %%
eval_env.action_space.sample()
# Out:
# array([7.2981948e+03, 3.1756051e-02, 2.3891046e+00, 4.0967622e+00,
#        5.5271277e+00], dtype=float32)

# %% [markdown]
# # Custom callback function

# %%
class RewardPlateauEscapeCallback(BaseCallback):
    def __init__(self, eval_env, threshold=0.01, patience=3, verbose=1):
        super().__init__(verbose)
        self.eval_env = eval_env
        self.threshold = threshold
        self.patience = patience
        self.recent_rewards = []
    
    def _on_rollout_end(self):
        """Called at the end of each rollout"""
        mean_reward = self.evaluate_agent()
        self.recent_rewards.append(mean_reward)
        
        # Keep only the last 'patience' number of rewards
        if len(self.recent_rewards) > self.patience:
            self.recent_rewards.pop(0)
        
        # Check for plateau only when we have enough data points
        if len(self.recent_rewards) == self.patience:
            reward_changes = np.diff(self.recent_rewards)
            if np.all(np.abs(reward_changes) < self.threshold):
                if self.verbose:
                    print(f"\n[Plateau Detected] Forcing Exploration Jump at step {self.num_timesteps}")
                    print(f"Recent rewards: {self.recent_rewards}")
                    print(f"Reward changes: {reward_changes}")
                self.force_exploration()
    
    def evaluate_agent(self, n_eval_episodes=3):
        """Evaluate the current agent performance"""
        total_rewards = []
        for _ in range(n_eval_episodes):
            obs = self.eval_env.reset()
    
            if isinstance(obs, (list, tuple)) and len(obs) == 1:
                obs = obs[0]

    
            done = False
            ep_reward = 0.0
    
            while not done:
                action, _ = self.model.predict(obs, deterministic=True)
                step_result = self.eval_env.step(action)
    
                # Handle old (4) and new (5) Gym step API
                if len(step_result) == 5:
                    obs, reward, terminated, truncated, info = step_result
                    done = terminated or truncated
                else:
                    obs, reward, done, info = step_result
    
                # If reward is in array format (for VecEnv), extract scalar
                if isinstance(reward, (list, np.ndarray)):
                    reward = reward[0]
    
                ep_reward += reward
    
            total_rewards.append(ep_reward)
    
        return np.mean(total_rewards)

    
    def force_exploration(self):
        """Force environment to reset and escape local optimum."""
        # Access the training environment
        training_env = self.training_env
        
        # Handle VecNormalize wrapper
        if hasattr(training_env, 'venv'):
            # training_env is VecNormalize, access underlying vectorized env
            underlying_env = training_env.venv
            if hasattr(underlying_env, 'envs') and len(underlying_env.envs) > 0:
                # Multiple environments in vector
                for i, env in enumerate(underlying_env.envs):
                    if hasattr(env, "reset"):
                        env.reset()
                        if self.verbose:
                            print(f"[Exploration Jump] Env {i} triggered.")
                    else:
                        if self.verbose:
                            print(f"[Warning] Env {i} does not support reset().")
            elif hasattr(underlying_env, 'envs') and len(underlying_env.envs) == 1:
                # Single environment in DummyVecEnv
                env = underlying_env.envs[0]
                if hasattr(env, "reset"):
                    env.reset()
                    if self.verbose:
                        print("[Exploration Jump] Environment reset triggered.")
                else:
                    if self.verbose:
                        print("[Warning] Environment is not able to access reset().")
            else:
                if self.verbose:
                    print("[Warning] Could not access environment through VecNormalize wrapper.")
        elif hasattr(training_env, "envs") and len(training_env.envs) > 0:
            # Direct vectorized environment without VecNormalize
            for i, env in enumerate(training_env.envs):
                if hasattr(env, "reset"):
                    env.reset()
                    if self.verbose:
                        print(f"[Exploration Jump] Env {i} reset triggered.")
                else:
                    if self.verbose:
                        print(f"[Warning] Env {i} does not support reset().")
        else:
            # Fallback: try direct access
            if hasattr(training_env, "reset"):
                training_env.reset()
                if self.verbose:
                    print("[Exploration Jump] Environment reset triggered.")
            else:
                if self.verbose:
                    print("[Warning] Environment does not support reset().")
    
    def _on_step(self):
        """Called after each step (required by BaseCallback)"""
        return True  # Continue training

# %% [markdown]
# # Callbacks declaration for the model

# %%
# Evaluation Callback
eval_callback = EvalCallback(
    eval_env,
    best_model_save_path=os.path.join(log_dir, "Orbit_model_v0"),
    log_path=log_dir,
    eval_freq=1000,
    n_eval_episodes=5,  
    deterministic=True,
    render=False,
)

# %%
# Custom relocation callback
relocation_callback = RewardPlateauEscapeCallback(
    eval_env,
    threshold =0.25, # Minimum change in reward to be considered as 'Improvement'
    patience = 3,  # Number of episodes to be checked 
    verbose = 1
)

# %% [markdown]
# # Check for any warnings before starting training

# %%
from stable_baselines3.common.env_checker import check_env
check_env(raw_env, warn=True)
# Out:
# C:\Users\Manan\anaconda3\Lib\site-packages\stable_baselines3\common\env_checker.py:462: UserWarning: We recommend you to use a symmetric and normalized Box action space (range=[-1, 1]) cf. https://stable-baselines3.readthedocs.io/en/master/guide/rl_tips.html
#   warnings.warn(

# %%
from stable_baselines3.common.env_checker import check_env
check_env(eval_env_raw, warn=True)

# %% [markdown]
# # Define the Model policy, algorithm and other parameters

# %%
model = A2C(
    "MultiInputPolicy",
    vec_env,
    learning_rate = 0.0001,
    n_steps = 32,
    gamma = 0.99,
    gae_lambda = 0.98,
    ent_coef = 0.03,
    vf_coef = 0.75,
    max_grad_norm = 0.6,
    rms_prop_eps = 1e-5,   # Default value -> change if unstable updates
    use_rms_prop = True,
    use_sde = True,
    sde_sample_freq = 75,  
    normalize_advantage = True,
    stats_window_size = 100,
    tensorboard_log=log_dir,
    policy_kwargs = {
        'activation_fn' : LeakyReLU,
        'net_arch' : {
                'pi': [512, 256, 128],
                'vf': [512, 256, 128]
            },
        'ortho_init' : True,
        'squash_output' : True
    },
    verbose=1,
    seed = 42,
)

model.set_logger(new_logger)
# Out:
# Using cuda device

# %% [markdown]
# # Start training

# %%
model.learn(
    total_timesteps=60000, 
    callback=[relocation_callback, eval_callback]
)
# Out:
# [Plateau Detected] Forcing Exploration Jump at step 96
# Recent rewards: [1.7210115989049275, 1.7210124333699544, 1.7210071881612141]
# Reward changes: [ 8.34465027e-07 -5.24520874e-06]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 128
# Recent rewards: [1.7210124333699544, 1.7210071881612141, 1.7210090160369873]
# Reward changes: [-5.24520874e-06  1.82787577e-06]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 160
# Recent rewards: [1.7210071881612141, 1.7210090160369873, 1.721005956331889]
# Reward changes: [ 1.82787577e-06 -3.05970510e-06]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 192
# Recent rewards: [1.7210090160369873, 1.721005956331889, 1.7210020621617634]
# Reward changes: [-3.05970510e-06 -3.89417013e-06]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 224
# Recent rewards: [1.721005956331889, 1.7210020621617634, 1.7210005124409993]
# Reward changes: [-3.89417013e-06 -1.54972076e-06]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 256
# Recent rewards: [1.7210020621617634, 1.7210005124409993, 1.7210026184717815]
# Reward changes: [-1.54972076e-06  2.10603078e-06]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 288
# Recent rewards: [1.7210005124409993, 1.7210026184717815, 1.7210026979446411]
# Reward changes: [2.10603078e-06 7.94728596e-08]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 320
# Recent rewards: [1.7210026184717815, 1.7210026979446411, 1.7210025389989216]
# Reward changes: [ 7.94728596e-08 -1.58945719e-07]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 352
# Recent rewards: [1.7210026979446411, 1.7210025389989216, 1.7210034529368083]
# Reward changes: [-1.58945719e-07  9.13937887e-07]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 384
# Recent rewards: [1.7210025389989216, 1.7210034529368083, 1.7210018237431843]
# Reward changes: [ 9.13937887e-07 -1.62919362e-06]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 416
# Recent rewards: [1.7210034529368083, 1.7210018237431843, 1.7209996382395427]
# Reward changes: [-1.62919362e-06 -2.18550364e-06]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 448
# Recent rewards: [1.7210018237431843, 1.7209996382395427, 1.7209994792938232]
# Reward changes: [-2.18550364e-06 -1.58945719e-07]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 480
# Recent rewards: [1.7209996382395427, 1.7209994792938232, 1.7209973335266113]
# Reward changes: [-1.58945719e-07 -2.14576721e-06]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 512
# Recent rewards: [1.7209994792938232, 1.7209973335266113, 1.7209988435109456]
# Reward changes: [-2.14576721e-06  1.50998433e-06]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 544
# Recent rewards: [1.7209973335266113, 1.7209988435109456, 1.7209986050923665]
# Reward changes: [ 1.50998433e-06 -2.38418579e-07]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 576
# Recent rewards: [1.7209988435109456, 1.7209986050923665, 1.7209963003794353]
# Reward changes: [-2.38418579e-07 -2.30471293e-06]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 608
# Recent rewards: [1.7209986050923665, 1.7209963003794353, 1.7209947903951008]
# Reward changes: [-2.30471293e-06 -1.50998433e-06]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 640
# Recent rewards: [1.7209963003794353, 1.7209947903951008, 1.7209972937901814]
# Reward changes: [-1.50998433e-06  2.50339508e-06]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 672
# Recent rewards: [1.7209947903951008, 1.7209972937901814, 1.720997929573059]
# Reward changes: [2.50339508e-06 6.35782878e-07]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 704
# Recent rewards: [1.7209972937901814, 1.720997929573059, 1.720999797185262]
# Reward changes: [6.35782878e-07 1.86761220e-06]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 736
# Recent rewards: [1.720997929573059, 1.720999797185262, 1.7209983666737874]
# Reward changes: [ 1.86761220e-06 -1.43051147e-06]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 768
# Recent rewards: [1.720999797185262, 1.7209983666737874, 1.721000075340271]
# Reward changes: [-1.43051147e-06  1.70866648e-06]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 800
# Recent rewards: [1.7209983666737874, 1.721000075340271, 1.7209997177124023]
# Reward changes: [ 1.70866648e-06 -3.57627869e-07]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 832
# Recent rewards: [1.721000075340271, 1.7209997177124023, 1.7209991614023845]
# Reward changes: [-3.57627869e-07 -5.56310018e-07]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 864
# Recent rewards: [1.7209997177124023, 1.7209991614023845, 1.720996578534444]
# Reward changes: [-5.56310018e-07 -2.58286794e-06]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 896
# Recent rewards: [1.7209991614023845, 1.720996578534444, 1.7209988435109456]
# Reward changes: [-2.58286794e-06  2.26497650e-06]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 928
# Recent rewards: [1.720996578534444, 1.7209988435109456, 1.7209981282552083]
# Reward changes: [ 2.26497650e-06 -7.15255737e-07]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 960
# Recent rewards: [1.7209988435109456, 1.7209981282552083, 1.720998207728068]
# Reward changes: [-7.15255737e-07  7.94728598e-08]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 992
# Recent rewards: [1.7209981282552083, 1.720998207728068, 1.7209958632787068]
# Reward changes: [ 7.94728598e-08 -2.34444936e-06]
# [Exploration Jump] Env 0 triggered.
# C:\Users\Manan\anaconda3\Lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=1000, episode_reward=1.72 +/- 0.00
# Episode length: 1.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 1        |
# |    mean_reward        | 1.72     |
# | time/                 |          |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -2.95    |
# |    explained_variance | -2.82    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 31       |
# |    policy_loss        | 0.0789   |
# |    std                | 1        |
# |    value_loss         | 16.8     |
# ------------------------------------
# New best mean reward!
#
# [Plateau Detected] Forcing Exploration Jump at step 1024
# Recent rewards: [1.720998207728068, 1.7209958632787068, 1.7210098505020142]
# Reward changes: [-2.34444936e-06  1.39872233e-05]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 1056
# Recent rewards: [1.7209958632787068, 1.7210098505020142, 1.7210095326105754]
# Reward changes: [ 1.39872233e-05 -3.17891439e-07]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 1088
# Recent rewards: [1.7210098505020142, 1.7210095326105754, 1.7210094531377156]
# Reward changes: [-3.17891439e-07 -7.94728598e-08]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 1120
# Recent rewards: [1.7210095326105754, 1.7210094531377156, 1.721009890238444]
# Reward changes: [-7.94728598e-08  4.37100729e-07]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 1152
# Recent rewards: [1.7210094531377156, 1.721009890238444, 1.7210091749827068]
# Reward changes: [ 4.37100729e-07 -7.15255737e-07]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 1184
# Recent rewards: [1.721009890238444, 1.7210091749827068, 1.7210089763005574]
# Reward changes: [-7.15255737e-07 -1.98682149e-07]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 1216
# Recent rewards: [1.7210091749827068, 1.7210089763005574, 1.7210084199905396]
# Reward changes: [-1.98682149e-07 -5.56310018e-07]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 1248
# Recent rewards: [1.7210089763005574, 1.7210084199905396, 1.721009095509847]
# Reward changes: [-5.56310018e-07  6.75519307e-07]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 1280
# Recent rewards: [1.7210084199905396, 1.721009095509847, 1.7210105260213215]
# Reward changes: [6.75519307e-07 1.43051147e-06]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 1312
# Recent rewards: [1.721009095509847, 1.7210105260213215, 1.721009651819865]
# Reward changes: [ 1.43051147e-06 -8.74201457e-07]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 1344
# Recent rewards: [1.7210105260213215, 1.721009651819865, 1.7210101286570232]
# Reward changes: [-8.74201457e-07  4.76837158e-07]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 1376
# Recent rewards: [1.721009651819865, 1.7210101286570232, 1.7210100094477336]
# Reward changes: [ 4.76837158e-07 -1.19209290e-07]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 1408
# Recent rewards: [1.7210101286570232, 1.7210100094477336, 1.7210090557734172]
# Reward changes: [-1.19209290e-07 -9.53674316e-07]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 1440
# Recent rewards: [1.7210100094477336, 1.7210090557734172, 1.7210091352462769]
# Reward changes: [-9.53674316e-07  7.94728596e-08]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 1472
# Recent rewards: [1.7210090557734172, 1.7210091352462769, 1.7210102876027424]
# Reward changes: [7.94728596e-08 1.15235647e-06]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 1504
# Recent rewards: [1.7210091352462769, 1.7210102876027424, 1.721009373664856]
# Reward changes: [ 1.15235647e-06 -9.13937886e-07]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 1536
# Recent rewards: [1.7210102876027424, 1.721009373664856, 1.7210105657577515]
# Reward changes: [-9.13937886e-07  1.19209290e-06]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 1568
# Recent rewards: [1.721009373664856, 1.7210105657577515, 1.7210101286570232]
# Reward changes: [ 1.19209290e-06 -4.37100728e-07]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 1600
# Recent rewards: [1.7210105657577515, 1.7210101286570232, 1.7210092544555664]
# Reward changes: [-4.37100728e-07 -8.74201457e-07]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 1632
# Recent rewards: [1.7210101286570232, 1.7210092544555664, 1.72100826104482]
# Reward changes: [-8.74201457e-07 -9.93410746e-07]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 1664
# Recent rewards: [1.7210092544555664, 1.72100826104482, 1.721006194750468]
# Reward changes: [-9.93410746e-07 -2.06629435e-06]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 1696
# Recent rewards: [1.72100826104482, 1.721006194750468, 1.721005876859029]
# Reward changes: [-2.06629435e-06 -3.17891439e-07]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 1728
# Recent rewards: [1.721006194750468, 1.721005876859029, 1.7210079431533813]
# Reward changes: [-3.17891439e-07  2.06629435e-06]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 1760
# Recent rewards: [1.721005876859029, 1.7210079431533813, 1.7210052410761516]
# Reward changes: [ 2.06629435e-06 -2.70207723e-06]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 1792
# Recent rewards: [1.7210079431533813, 1.7210052410761516, 1.721004803975423]
# Reward changes: [-2.70207723e-06 -4.37100729e-07]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 1824
# Recent rewards: [1.7210052410761516, 1.721004803975423, 1.7210068305333455]
# Reward changes: [-4.37100729e-07  2.02655792e-06]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 1856
# Recent rewards: [1.721004803975423, 1.7210068305333455, 1.7210044066111247]
# Reward changes: [ 2.02655792e-06 -2.42392222e-06]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 1888
# Recent rewards: [1.7210068305333455, 1.7210044066111247, 1.7210055987040203]
# Reward changes: [-2.42392222e-06  1.19209290e-06]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 1920
# Recent rewards: [1.7210044066111247, 1.7210055987040203, 1.721004565556844]
# Reward changes: [ 1.19209290e-06 -1.03314718e-06]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 1952
# Recent rewards: [1.7210055987040203, 1.721004565556844, 1.7210052410761516]
# Reward changes: [-1.03314718e-06  6.75519308e-07]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 1984
# Recent rewards: [1.721004565556844, 1.7210052410761516, 1.7210042476654053]
# Reward changes: [ 6.75519308e-07 -9.93410746e-07]
# [Exploration Jump] Env 0 triggered.
# Eval num_timesteps=2000, episode_reward=1.72 +/- 0.00
# Episode length: 1.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 1        |
# |    mean_reward        | 1.72     |
# | time/                 |          |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -3.78    |
# |    explained_variance | -4.8     |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 62       |
# |    policy_loss        | 0.192    |
# |    std                | 0.999    |
# |    value_loss         | 1.08     |
# ------------------------------------
#
# [Plateau Detected] Forcing Exploration Jump at step 2016
# Recent rewards: [1.7210052410761516, 1.7210042476654053, 1.7210051616032918]
# Reward changes: [-9.93410746e-07  9.13937886e-07]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 2048
# Recent rewards: [1.7210042476654053, 1.7210051616032918, 1.7210044066111247]
# Reward changes: [ 9.13937886e-07 -7.54992167e-07]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 2080
# Recent rewards: [1.7210051616032918, 1.7210044066111247, 1.7210044463475545]
# Reward changes: [-7.54992167e-07  3.97364297e-08]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 2112
# Recent rewards: [1.7210044066111247, 1.7210044463475545, 1.7210042476654053]
# Reward changes: [ 3.97364297e-08 -1.98682149e-07]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 2144
# Recent rewards: [1.7210044463475545, 1.7210042476654053, 1.7210049629211426]
# Reward changes: [-1.98682149e-07  7.15255737e-07]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 2176
# Recent rewards: [1.7210042476654053, 1.7210049629211426, 1.7210052410761516]
# Reward changes: [7.15255737e-07 2.78155009e-07]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 2208
# Recent rewards: [1.7210049629211426, 1.7210052410761516, 1.7210069100062053]
# Reward changes: [2.78155009e-07 1.66893005e-06]
# [Exploration Jump] Env 0 triggered.
#
# [Plateau Detected] Forcing Exploration Jump at step 2240
# Recent rewards: [1.7210052410761516, 1.7210069100062053, 1.7210059960683186]
# Reward changes: [ 1.66893005e-06 -9.13937887e-07]
# [Exploration Jump] Env 0 triggered.
# KeyboardInterrupt

# %% [markdown]
# # additional training

# %%
model.learn(total_timesteps=5000, reset_num_timesteps = False, callback=[relocation_callback, eval_callback])

# %% [markdown]
# # Test model prediction

# %%
obs = vec_env.reset()
action, _ = model.predict(obs, deterministic=True)

obs, reward, terminated, info = vec_env.step(action)

print("Orbit parameters:", action[0])
print("A2C Reward:", reward[0])
print("Objectives met:", info[0]['all_objectives_met'])
# Out:
# Orbit parameters: [7.5276489e+03 4.8966762e-02 1.6175920e+00 3.1265836e+00 3.0854557e+00]
# A2C Reward: 10.0
# Objectives met: True

# %% [markdown]
# # Tensorboard logs

# %%
# %load_ext tensorboard
# %tensorboard --logdir ./logs
# Out:
#       <iframe id="tensorboard-frame-aae388c6b7712c35" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-aae388c6b7712c35");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# # Saving model

# %%
model.save("a2c_orbit_prediction_RL_model(2000_time_steps)")
vec_env.save("a2c_orbit_vec_normalize.pkl")
